# %%
import pandas as pd

midasData = pd.read_excel('MIDAS_Data.xlsx')
print(midasData)
# Out:
#       Data        ESI    ESI_D11    GDP_RB    GGDP_RB
# 0   2005Q2  107.60100  103.42770  17834.95  108.46660
# 1   2005Q3  110.09370  104.90730  22518.84  108.63430
# 2   2005Q4  101.50730  105.44200  22035.05  110.75150
# 3   2006Q1  101.83100  107.45600  18325.54  111.26410
# 4   2006Q2  113.13570  108.85840  19554.39  109.64080
# ..     ...        ...        ...       ...        ...
# 62  2020Q4   88.81167   91.45426  32474.30   99.75548
# 63  2021Q1   86.84850   90.76043  28898.30  101.50690
# 64  2021Q2        NaN        NaN  30511.90  106.01990
# 65  2021Q3        NaN        NaN  33739.50  101.65990
# 66  2021Q4        NaN        NaN  32906.30  101.33030
#
# [67 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

midasData.plot(x='ESI_D11', y='GGDP_RB', kind='scatter')
plt.show()

# %%
# from sklearn.cluster import KMeans
#
# kmeans = KMeans(n_clusters=2).fit(midasData)
# centroids = kmeans.cluster_centers_
# print(centroids)
#
# plt.scatter(midasData['ESI'], midasData['GGDP'], c= kmeans.labels_.astype(), s=50, alpha=0.5)
# plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 from sklearn.cluster import KMeans
# ----> 3 kmeans = KMeans(n_clusters=2).fit(midasData)
#       4 centroids = kmeans.cluster_centers_
#       5 print(centroids)
#
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\sklearn\cluster\_kmeans.py:1367, in KMeans.fit(self, X, y, sample_weight)
#    1341 def fit(self, X, y=None, sample_weight=None):
#    1342     """Compute k-means clustering.
#    1343
#    1344     Parameters
#    (...)
#    1365         Fitted estimator.
#    1366     """
# -> 1367     X = self._validate_data(
#    1368         X,
#    1369         accept_sparse="csr",
#    1370         dtype=[np.float64, np.float32],
#    1371         order="C",
#    1372         copy=self.copy_x,
#    1373         accept_large_sparse=False,
#    1374     )
# ...

# %%
import os
os.getcwd()

import pandas
import seaborn

dataset = pandas.read_excel('MIDAS_Data.xlsx')
print(dataset)
# Out:
#       Data        ESI    ESI_D11    GDP_RB    GGDP_RB
# 0   2005Q2  107.60100  103.42770  17834.95  108.46660
# 1   2005Q3  110.09370  104.90730  22518.84  108.63430
# 2   2005Q4  101.50730  105.44200  22035.05  110.75150
# 3   2006Q1  101.83100  107.45600  18325.54  111.26410
# 4   2006Q2  113.13570  108.85840  19554.39  109.64080
# ..     ...        ...        ...       ...        ...
# 62  2020Q4   88.81167   91.45426  32474.30   99.75548
# 63  2021Q1   86.84850   90.76043  28898.30  101.50690
# 64  2021Q2        NaN        NaN  30511.90  106.01990
# 65  2021Q3        NaN        NaN  33739.50  101.65990
# 66  2021Q4        NaN        NaN  32906.30  101.33030
#
# [67 rows x 5 columns]

# %%
ggpd = midasData.GGDP_RB
print(ggpd)
# Out:
# 0     108.46660
# 1     108.63430
# 2     110.75150
# 3     111.26410
# 4     109.64080
#         ...
# 62     99.75548
# 63    101.50690
# 64    106.01990
# 65    101.65990
# 66    101.33030
# Name: GGDP_RB, Length: 67, dtype: float64

# %%
ggpd.plot(figsize=(12,6))
# Out:
# <AxesSubplot: >

# %%
res = ggpd.describe()
ggpd.hist()
print(res)
# Out:
# count     67.000000
# mean     103.395286
# std        4.652951
# min       95.519030
# 25%      100.026265
# 50%      101.853300
# 75%      108.304350
# max      111.331100
# Name: GGDP_RB, dtype: float64

# %%
import os
os.getcwd()

import pandas
import seaborn

dataset = pandas.read_excel('MIDAS_Data2.xlsx')
print(dataset)
ggpd1 = midasData.ESI_D11
print(ggpd1)
ggpd1.plot(figsize=(12,6))
# Out:
#         Data      ESI    ESI_D11       GDP      GGDP
# 0    2005M05  106.872  101.33930  3804.969       NaN
# 1    2005M06  108.330  102.48490  4407.503       NaN
# 2    2005M07  110.077  103.47930  4187.836       NaN
# 3    2005M08  111.918  104.86830  5059.122       NaN
# 4    2005M09  108.286  106.86300  5223.258       NaN
# ..       ...      ...        ...       ...       ...
# 185  2020M10   92.860   92.93054  7072.686  100.6062
# 186  2020M11   87.826   91.29998  6524.223  101.1781
# 187  2020M12   85.749   91.43645  7115.601   99.1000
# 188  2021M01   85.157   90.83689  5666.924  101.3000
# 189  2021M02   88.540   93.30433       NaN       NaN
#
# [190 rows x 5 columns]
# 0     103.42770
# 1     104.90730
# 2     105.44200
# 3     107.45600
# 4     108.85840
#         ...
# 62     91.45426
# 63     90.76043
# 64          NaN
# 65          NaN
# 66          NaN
# Name: ESI_D11, Length: 67, dtype: float64
# <AxesSubplot: >
